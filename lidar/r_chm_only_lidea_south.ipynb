# %%
library(terra)
library(sf)
library(raster)
library(tmap)
library(tmaptools)
library(lidR)
library(RStoolbox)
library(future)
# Out:
# terra 1.5.21
#
# Linking to GEOS 3.9.1, GDAL 3.2.1, PROJ 7.2.1; sf_use_s2() is TRUE
#
# Loading required package: sp
#
#
# Attaching package: 'lidR'
#
#
# The following objects are masked from 'package:raster':
#
#     area, crs, crs<-, projection, projection<-, wkt
#
#
# The following object is masked from 'package:sp':
#
#     wkt
#
#
# The following objects are masked from 'package:terra':
#
#     area, crs, crs<-

# %% [markdown]
# ***LiDAR***

# %%
las_cat <- catalog("I:\\LiDea II and South\\LiDea South\\LAZ_v2_CGVD2013a")  # Use catalog instead of readLAScatalog
# projection(las_cat) <- "+proj=utm +zone=17 +ellps=GRS80 +datum=NAD83 +units=m +no_defs "
summary(las_cat)
las_check(las_cat)
# Out:
# class       : LAScatalog (v1.4 format 6)
# extent      : 537000, 564000, 6097000, 6118000 (xmin, xmax, ymin, ymax)
# coord. ref. : NAD83(CSRS) / UTM zone 12N
# area        : 328.35 km²
# points      : 9.72 billion points
# density     : 29.6 points/m²
# density     : 19.6 pulses/m²
# num. files  : 342
# proc. opt.  : buffer: 30 | chunk: 0
# input opt.  : select: * | filter:
# output opt. : in memory | w2w guaranteed | merging enabled
# drivers     :
#  - Raster : format = GTiff  NAflag = -999999
#  - stars : NA_value = -999999
#  - SpatRaster : overwrite = FALSE  NAflag = -999999
#  - SpatVector : overwrite = FALSE
#  - LAS : no parameter
#  - Spatial : overwrite = FALSE
#  - sf : quiet = TRUE
#  - data.frame : no parameter
#
#  Checking headers consistency
#   - Checking file version consistency... <U+2713>
#   - Checking scale consistency... <U+2713>
#   - Checking offset consistency... <U+2713>
#   - Checking point type consistency... <U+2713>
#   - Checking VLR consistency... <U+2713>
#   - Checking CRS consistency... <U+2713>
#  Checking the headers
#   - Checking scale factor validity... <U+2713>
#   - Checking Point Data Format ID validity... <U+2713>
#  Checking preprocessing already done
#   - Checking negative outliers...
#     <U+26A0> 1 file(s) with points below 0
#   - Checking normalization... no
#  Checking the geometry
#   - Checking overlapping tiles... <U+2713>
#   - Checking point indexation... no

# %% [markdown]
# ***Creating a DTM***

# %%
opt_chunk_size(las_cat) <- 500
# plot(las_cat, chunk_pattern = TRUE)
opt_chunk_buffer(las_cat) <- 20
plot(las_cat, chunk_pattern = TRUE)
summary(las_cat)
las_cat@output_options$drivers$Raster$param$overwrite <- TRUE  # overwrite rasters
# Out:
# class       : LAScatalog (v1.4 format 6)
# extent      : 537000, 564000, 6097000, 6118000 (xmin, xmax, ymin, ymax)
# coord. ref. : NAD83(CSRS) / UTM zone 12N
# area        : 328.35 km²
# points      : 9.72 billion points
# density     : 29.6 points/m²
# density     : 19.6 pulses/m²
# num. files  : 342
# proc. opt.  : buffer: 20 | chunk: 500
# input opt.  : select: * | filter:
# output opt. : in memory | w2w guaranteed | merging enabled
# drivers     :
#  - Raster : format = GTiff  NAflag = -999999
#  - stars : NA_value = -999999
#  - SpatRaster : overwrite = FALSE  NAflag = -999999
#  - SpatVector : overwrite = FALSE
#  - LAS : no parameter
#  - Spatial : overwrite = FALSE
#  - sf : quiet = TRUE
#  - data.frame : no parameter
# Plot with title "Pattern of chunks"

# %%
opt_output_files(las_cat) <- "I:\\LiDea II and South\\LiDea South\\dtm\\dtm_{XLEFT}_{YBOTTOM}"
dtm <- grid_terrain(las_cat, res = 2, knnidw(k = 10, p = 2), keep_lowest = FALSE)
# Out:
# Warning message:
# "There were 2 degenerated ground points. Some X Y Z coordinates were repeated. They were removed."
# Warning message:
# "There were 39 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 4 degenerated ground points. Some X Y Z coordinates were repeated. They were removed."
# Warning message:
# "There were 48 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 4 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 9 degenerated ground points. Some X Y Z coordinates were repeated. They were removed."
# Warning message:
# "There were 114 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 3 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 3 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 9 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 4 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 11 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 12 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 9 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 17 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 6 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 2 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 7 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 5 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 5 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 2 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 1 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 1 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 4 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 7 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 1 degenerated ground points. Some X Y Z coordinates were repeated. They were removed."
# Warning message:
# "There were 3 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 2 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 4 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 1 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 1 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 9 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 3 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 3 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 14 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 9 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 4 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 13 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 5 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 6 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 6 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 2 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 5 degenerated ground points. Some X Y Z coordinates were repeated. They were removed."
# Warning message:
# "There were 9 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 3 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 4 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 1 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 4 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 2 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 1 degenerated ground points. Some X Y Z coordinates were repeated. They were removed."
# Warning message:
# "There were 5 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 4 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 1 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 5 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 1 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 5 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 7 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 2 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 4 degenerated ground points. Some X Y Z coordinates were repeated. They were removed."
# Warning message:
# "There were 25 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 9 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 3 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 11 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 14 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 15 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 4 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 4 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 1 degenerated ground points. Some X Y Z coordinates were repeated. They were removed."
# Warning message:
# "There were 1 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 5 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 5 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 4 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 6 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 1 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 2 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 2 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 5 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 59 degenerated ground points. Some X Y Z coordinates were repeated. They were removed."
# Warning message:
# "There were 349 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 1 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 2 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 11 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 4 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 1 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 11 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 9 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 11 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 23 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 7 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 10 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 4 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 4 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 2 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 7 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 1 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 3 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 11 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 31 degenerated ground points. Some X Y Z coordinates were repeated. They were removed."
# Warning message:
# "There were 222 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 1 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 4 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 4 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 1 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 4 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 8 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 3 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 4 degenerated ground points. Some X Y Z coordinates were repeated. They were removed."
# Warning message:
# "There were 19 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 13 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 9 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 11 degenerated ground points. Some X Y Z coordinates were repeated. They were removed."
# Warning message:
# "There were 82 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 11 degenerated ground points. Some X Y Z coordinates were repeated. They were removed."
# Warning message:
# "There were 88 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 10 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 8 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 10 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 7 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 9 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 7 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 7 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 3 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 5 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 5 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 4 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 7 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 3 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 40 degenerated ground points. Some X Y Z coordinates were repeated. They were removed."
# Warning message:
# "There were 186 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 19 degenerated ground points. Some X Y Z coordinates were repeated. They were removed."
# Warning message:
# "There were 78 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 2 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 3 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 6 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 5 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 11 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 15 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 13 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 2 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 9 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 4 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 5 degenerated ground points. Some X Y Z coordinates were repeated. They were removed."
# Warning message:
# "There were 87 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 3 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 9 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 3 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 5 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 9 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 28 degenerated ground points. Some X Y Z coordinates were repeated. They were removed."
# Warning message:
# "There were 145 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 3 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 3 degenerated ground points. Some X Y Z coordinates were repeated. They were removed."
# Warning message:
# "There were 32 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 4 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 3 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 4 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 24 degenerated ground points. Some X Y Z coordinates were repeated. They were removed."
# Warning message:
# "There were 158 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 5 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 10 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 6 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 13 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 5 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 5 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 1 degenerated ground points. Some X Y Z coordinates were repeated. They were removed."
# Warning message:
# "There were 2 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 7 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 5 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 8 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 1 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 5 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 3 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 1 degenerated ground points. Some X Y Z coordinates were repeated. They were removed."
# Warning message:
# "There were 4 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 17 degenerated ground points. Some X Y Z coordinates were repeated. They were removed."
# Warning message:
# "There were 115 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 3 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 4 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 5 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 3 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 8 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 4 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 1 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 4 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 8 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 1 degenerated ground points. Some X Y Z coordinates were repeated. They were removed."
# Warning message:
# "There were 7 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 2 degenerated ground points. Some X Y Z coordinates were repeated. They were removed."
# Warning message:
# "There were 14 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 1 degenerated ground points. Some X Y Z coordinates were repeated. They were removed."
# Warning message:
# "There were 6 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 5 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 2 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 4 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 3 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 2 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 10 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 5 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 6 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 1 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 4 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 1 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 17 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 5 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 2 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 8 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 2 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 16 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 3 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 37 degenerated ground points. Some X Y Z coordinates were repeated. They were removed."
# Warning message:
# "There were 246 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 27 degenerated ground points. Some X Y Z coordinates were repeated. They were removed."
# Warning message:
# "There were 139 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 7 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 12 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 21 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 7 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 4 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 4 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 2 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 2 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 5 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 4 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 1 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 4 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 1 degenerated ground points. Some X Y Z coordinates were repeated. They were removed."
# Warning message:
# "There were 3 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 2 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 7 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 13 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 3 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 7 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 7 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 3 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 2 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 9 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 16 degenerated ground points. Some X Y Z coordinates were repeated. They were removed."
# Warning message:
# "There were 74 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 19 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 13 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 4 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 13 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 13 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 7 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 6 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 3 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 3 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 2 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 2 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 5 degenerated ground points. Some X Y Z coordinates were repeated. They were removed."
# Warning message:
# "There were 15 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 6 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 12 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 5 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 5 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 5 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 2 degenerated ground points. Some X Y Z coordinates were repeated. They were removed."
# Warning message:
# "There were 10 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 8 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 12 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 11 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 9 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 8 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 9 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 26 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 16 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 4 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 5 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 2 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 1 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 3 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 2 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 2 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 4 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 3 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 3 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 10 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 13 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 5 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 6 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 3 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 1 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 4 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 3 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 7 degenerated ground points. Some X Y Z coordinates were repeated. They were removed."
# Warning message:
# "There were 70 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 10 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 9 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 3 degenerated ground points. Some X Y Z coordinates were repeated. They were removed."
# Warning message:
# "There were 15 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 18 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 10 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 4 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 3 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 6 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 3 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 1 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 6 degenerated ground points. Some X Y Z coordinates were repeated. They were removed."
# Warning message:
# "There were 18 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 1 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 2 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 3 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 1 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 4 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 3 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 2 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 2 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 3 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 1 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 7 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 3 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 26 degenerated ground points. Some X Y Z coordinates were repeated. They were removed."
# Warning message:
# "There were 159 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 6 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 9 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 1 degenerated ground points. Some X Y Z coordinates were repeated. They were removed."
# Warning message:
# "There were 7 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 9 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 13 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 4 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 1 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 3 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 3 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 2 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 29 degenerated ground points. Some X Y Z coordinates were repeated. They were removed."
# Warning message:
# "There were 209 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 3 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 1 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 5 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# ...
# Warning message:
# "There were 5 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 2 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 3 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 4 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 6 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 12 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 6 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 1 degenerated ground points. Some X Y Z coordinates were repeated. They were removed."
# Warning message:
# "There were 5 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 1 degenerated ground points. Some X Y Z coordinates were repeated. They were removed."
# Warning message:
# "There were 12 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 11 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 8 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 2 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 3 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 74 degenerated ground points. Some X Y Z coordinates were repeated. They were removed."
# Warning message:
# "There were 473 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 3 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 5 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 6 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 3 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 4 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 3 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 1 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 1 degenerated ground points. Some X Y Z coordinates were repeated. They were removed."
# Warning message:
# "There were 13 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 3 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 4 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 1 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 18 degenerated ground points. Some X Y Z coordinates were repeated. They were removed."
# Warning message:
# "There were 183 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 3 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 5 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 14 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 1 degenerated ground points. Some X Y Z coordinates were repeated. They were removed."
# Warning message:
# "There were 10 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 5 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 12 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 19 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 4 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 1 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 6 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 2 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 4 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 2 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 1 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 3 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 6 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 2 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 9 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 8 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 5 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 4 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 4 degenerated ground points. Some X Y Z coordinates were repeated. They were removed."
# Warning message:
# "There were 62 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 2 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 3 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 8 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 14 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 9 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 2 degenerated ground points. Some X Y Z coordinates were repeated. They were removed."
# Warning message:
# "There were 15 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 21 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 10 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 5 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 7 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 2 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 7 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 1 degenerated ground points. Some X Y Z coordinates were repeated. They were removed."
# Warning message:
# "There were 5 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 3 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 4 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 7 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 2 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 10 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 4 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 2 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 3 degenerated ground points. Some X Y Z coordinates were repeated. They were removed."
# Warning message:
# "There were 12 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 1 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 2 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 9 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 2 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 8 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 10 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 12 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 10 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 1 degenerated ground points. Some X Y Z coordinates were repeated. They were removed."
# Warning message:
# "There were 12 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 19 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 7 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 2 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 6 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 5 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 9 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 12 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 4 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 3 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 5 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 1 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 5 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 5 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 6 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 3 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 6 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 9 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 3 degenerated ground points. Some X Y Z coordinates were repeated. They were removed."
# Warning message:
# "There were 17 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."
# Warning message:
# "There were 2 degenerated ground points. Some X Y coordinates were repeated but with different Z coordinates. min Z were retained."

# %% [markdown]
# ***Plot DTM***

# %%
tm_shape(dtm) +
  tm_raster(style= "quantile", palette=get_brewer_pal("Greys", plot=FALSE)) +
  tm_layout(legend.outside = TRUE)

# %% [markdown]
# ***Creating CHM***

# %%
opt_output_files(las_cat) <- "I:\\LiDea II and South\\LiDea South\\norm\\norm_{XLEFT}_{YBOTTOM}"
lasnorm <- normalize_height(las_cat, dtm)

# %%
opt_output_files(lasnorm) <- "I:\\LiDea II and South\\LiDea South\\chm\\chm_{XLEFT}_{YBOTTOM}"
dsm <- grid_canopy(lasnorm, res = 2, pitfree(c(0,2,5,10,15), c(0, 1)))
